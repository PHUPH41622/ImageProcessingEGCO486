# %%
# %pip install ultralytics  # install
from ultralytics import YOLO, checks, hub

checks()  # checks
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5933.9/8062.4 GB disk)

# %%
hub.login('303465c047ad699cfd70223df3d45900505efc1b7f')

model = YOLO('https://hub.ultralytics.com/models/afzB2rSwmAOMNHrxuPWi')
results = model.train()
# Out:
# requirements: Ultralytics requirement ['hub-sdk>=0.0.12'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 3.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 10.8s, installed 1 package: ['hub-sdk>=0.0.12']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/afzB2rSwmAOMNHrxuPWi 🚀
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 66.8MB/s]
# Ultralytics 8.3.27 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...
