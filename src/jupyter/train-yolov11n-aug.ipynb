# %%
# %pip install ultralytics  # install
from ultralytics import YOLO, checks, hub

checks()  # checks
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5933.9/8062.4 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Cx14JqJobLYVjeCovFtb")
project = rf.workspace("phupha").project("product-detection-vizdm")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to product-detection-1 in yolov11:: 100%|██████████| 2132/2132 [00:00<00:00, 7752.77it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo11n.pt data={dataset.location}/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /kaggle/working
# Ultralytics 8.3.27 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...
